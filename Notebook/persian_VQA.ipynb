# %% [markdown]
# <a href="https://colab.research.google.com/github/maryamhashemi/Persian_VQA/blob/master/persian_VQA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Prerequesties

# %%
! pip install arabic_reshaper 
! pip install python-bidi
# Out:
# Collecting arabic_reshaper
#   Downloading https://files.pythonhosted.org/packages/1c/b8/9f87dc2fc6c2e087e448db9e7f66ca4d68c22e9d49a95e5aad22d77c74f1/arabic_reshaper-2.0.15-py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from arabic_reshaper) (46.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from arabic_reshaper) (0.16.0)
# Installing collected packages: arabic-reshaper
# Successfully installed arabic-reshaper-2.0.15
# Collecting python-bidi
#   Downloading https://files.pythonhosted.org/packages/33/b0/f942d146a2f457233baaafd6bdf624eba8e0f665045b4abd69d1b62d097d/python_bidi-0.4.2-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from python-bidi) (1.12.0)
# Installing collected packages: python-bidi
# Successfully installed python-bidi-0.4.2

# %%
import os
import re
import json
import numpy as np
from PIL import Image
import arabic_reshaper
from collections import Counter
import matplotlib.pyplot as plt
from bidi.algorithm import get_display
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Dense, LSTM, Dropout, Embedding, Multiply, Input

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Set Parameters

# %%
DROPOUT_RATE = 0.5
EMBEDDING_DIM = 100
EPOCHS = 50
BATCH_SIZE = 64
SEQ_LENGTH = 40
VOCAB_SIZE = 1000
OOV_TOK = "<OOV>"

BASE_PATH = '/content/drive/My Drive/Persian_VQA/'
QUESTION_TRAIN_PATH =   os.path.join(BASE_PATH, 'google-train_questions.json')
ANNOTATION_TRAIN_PATH = os.path.join(BASE_PATH, 'google-train-annotations.json')
IMAGE_TRAIN_PATH = os.path.join(BASE_PATH, 'train_images_1000')

QUESTION_VAL_PATH =   os.path.join(BASE_PATH, '...')
ANNOTATION_VAL_PATH = os.path.join(BASE_PATH, '...')
IMAGE_VAL_PATH = os.path.join(BASE_PATH, 'val_images_500')

QUESTION_TEST_PATH =   os.path.join(BASE_PATH, '...')
ANNOTATION_TEST_PATH = os.path.join(BASE_PATH, '...')
IMAGE_TEST_PATH = os.path.join(BASE_PATH, 'val_images_500')

# %% [markdown]
# ### Read Data

# %%
def read_image_paths(dir_path):
  ims = {}

  for filename in os.listdir(dir_path):
    if filename.endswith('.jpg'):
      image_id = int(re.findall('\d+', filename)[1])
      ims[image_id] = os.path.join(dir_path, filename)

  return ims

# %%
def load_and_proccess_image(image_path, model):
  im = load_img(image_path, target_size=(224,224,3))
  x = img_to_array(im)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model.predict(x)

  return features[0]

# %%
def read_images(paths):
  ims = {}
  base_model = VGG19(weights='imagenet', include_top=True)
  model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

  for image_id, image_path in paths.items():
    ims[image_id] = load_and_proccess_image(image_path, model)
  return ims

# %%
def get_train_image_paths():
  return read_image_paths(IMAGE_TRAIN_PATH)

# %%
def get_val_image_paths():
  return read_image_paths(IMAGE_VAL_PATH)

# %%
def get_test_image_paths():
  return read_image_paths(IMAGE_TEST_PATH)

# %%
def create_dataset(ims, qus, ann):
  qs = []
  answers = []
  qs_id = []
  im_id = []

  for q in qus['questions']:
    if q['image_id'] in ims.keys():
      qs.append(q['question'])
      qs_id.append(q['question_id'])
      im_id.append(q['image_id'])

  for ann in ann['annotations']:
    if ann['question_id'] in qs_id:
      answer_counts = Counter(a['answer'] for a in ann['answers'])
      answers.append(answer_counts.most_common(1)[0][0])

  return qs, answers, qs_id, im_id

# %%
def get_train_dataset():
  ims = get_train_image_paths()
  qs = json.load( open(QUESTION_TRAIN_PATH))
  ann = json.load( open(ANNOTATION_TRAIN_PATH))
  
  return create_dataset(ims, qs, ann)

# %%
def get_val_dataset():
  ims = get_val_image_paths()
  qs = json.load( open(QUESTION_TRAIN_PATH))
  ann = json.load( open(ANNOTATION_TRAIN_PATH))
  
  return create_dataset(ims, qs, ann)

# %%
def get_test_dataset():
  ims = get_test_image_paths()
  qs = json.load( open(QUESTION_TRAIN_PATH))
  ann = json.load( open(ANNOTATION_TRAIN_PATH))
  
  return create_dataset(ims, qs, ann)

# %%
def get_answers(answers):
  all_answers = np.unique(answers)

  answer_counts = Counter(a for a in train_answers)
  all_answers =[a[0] for a in answer_counts.most_common(300)]

  return all_answers

# %% [markdown]
# #### Visualize Data

# %%
def show_visualqa(qs, answer, image):
  im = Image.open(image)  
  plt.figure()
  plt.imshow(im)
  title = arabic_reshaper.reshape(qs + "\n" + answer)
  title = get_display(title) 
  plt.title(title)
  plt.axis('off')
  plt.show()

def visualize_train(num):
  ims = get_train_image_paths()
  show_visualqa(train_qs[num], train_answers[num], ims.get(train_image_ids[num]))

def visualize_test(num):
  ims = get_test_image_paths()
  show_visualqa(test_qs[num], test_answers[num], ims.get(train_image_ids[num]))

# %%
train_qs, train_answers, train_q_ids, train_image_ids = get_train_dataset()
val_qs, val_answers, val_q_ids, val_image_ids = get_val_dataset()
test_qs, test_answers, test_q_ids, test_image_ids = get_test_dataset()

print(len(train_qs))
print(len(train_answers))
print(len(train_q_ids))
print(len(train_image_ids))

print(len(val_qs))
print(len(val_answers))
print(len(val_q_ids))
print(len(val_image_ids))

print(len(test_qs))
print(len(test_answers))
print(len(test_q_ids))
print(len(test_image_ids))
# Out:
# 3000
# 3000
# 3000
# 3000
# 1500
# 1500
# 1500
# 1500
# 1500
# 1500
# 1500
# 1500

# %%
visualize_train(1100)
visualize_train(2200)
visualize_train(600)

# %% [markdown]
# #### Prepare questions to feed into network

# %%
tokenizer = Tokenizer(num_words = VOCAB_SIZE, oov_token=OOV_TOK)
word_index = tokenizer.word_index
tokenizer.fit_on_texts(train_qs)

train_X_seqs = tokenizer.texts_to_sequences(train_qs)
val_X_seqs = tokenizer.texts_to_sequences(val_qs)
test_X_seqs = tokenizer.texts_to_sequences(test_qs)

train_X_seqs = pad_sequences(train_X_seqs, maxlen=SEQ_LENGTH, padding='post')
val_X_seqs = pad_sequences(val_X_seqs, maxlen=SEQ_LENGTH, padding='post')
test_X_seqs = pad_sequences(test_X_seqs, maxlen=SEQ_LENGTH, padding='post')

train_X_seqs = np.array(train_X_seqs)
val_X_seqs = np.array(val_X_seqs)
test_X_seqs = np.array(test_X_seqs)

# %% [markdown]
# #### Prepare images to feed into network

# %%
train_ims = read_images(get_train_image_paths())
val_ims = read_images(get_val_image_paths())
test_ims = read_images(get_test_image_paths())

train_X_ims = [train_ims[id] for id in train_image_ids]
val_X_ims = [val_ims[id] for id in val_image_ids]
test_X_ims = [test_ims[id] for id in test_image_ids]

train_X_ims = np.array(train_X_ims)
val_X_ims = np.array(val_X_ims)
test_X_ims = np.array(test_X_ims)

# %%
np.save(BASE_PATH + 'train_X_ims.npy',train_X_ims)
np.save(BASE_PATH + 'val_X_ims.npy',val_X_ims)
np.save(BASE_PATH + 'test_X_ims.npy',test_X_ims)

# %%
train_X_ims = np.load(BASE_PATH + 'train_X_ims.npy')
val_X_ims = np.load(BASE_PATH + 'val_X_ims.npy')
test_X_ims = np.load(BASE_PATH + 'test_X_ims.npy')

# %%
print(train_X_ims.shape)
print(val_X_ims.shape)
print(test_X_ims.shape)
# Out:
# (3000, 4096)
# (1500, 4096)
# (1500, 4096)

# %% [markdown]
# #### Prepare labels of data.

# %%
all_answers = get_answers(train_answers)
num_answers = len(all_answers)
num_classes = num_answers +1 

train_answer_indices = []
val_answer_indices = []
test_answer_indices = []

for a in train_answers:
  if a in all_answers:
    train_answer_indices.append(all_answers.index(a))
  else:
    train_answer_indices.append(num_answers)
 

for a in val_answers:
  if a in all_answers:
    val_answer_indices.append(all_answers.index(a))
  else: 
    val_answer_indices.append(num_answers)

for a in test_answers:
  if a in all_answers:
    test_answer_indices.append(all_answers.index(a))
  else:
    test_answer_indices.append(num_answers)

train_Y = to_categorical(train_answer_indices)
val_Y = to_categorical(val_answer_indices)
test_Y = to_categorical(test_answer_indices)

print(train_Y.shape)
print(val_Y.shape)
# Out:
# (3000, 301)
# (1500, 301)

# %% [markdown]
# ### Build Vanilla Network

# %%
def img_model(img_input):
  x = Dense(1024, activation='tanh', input_dim = 4096)(img_input)

  return x

# %%
def qs_model(qs_input, num_words, embedding_dim, dropout_rate):

  x = Embedding(num_words, embedding_dim, input_length=SEQ_LENGTH, trainable = True)(qs_input)
  x = LSTM(units=512, return_sequences=True, input_shape= (None,embedding_dim))(x)
  x = Dropout(dropout_rate)(x)
  x = LSTM(units=512, return_sequences=False)(x)
  x = Dropout(dropout_rate)(x)
  x = Dense(1024, activation='tanh')(x)

  return x

# %%
def vanilla(num_classes, dropout_rate, num_words, embedding_dim):
  qs_input = Input(shape=(SEQ_LENGTH,))
  img_input = Input(shape=(4096,))

  CNN_model = img_model(img_input)
  LSTM_model = qs_model(qs_input, num_words, embedding_dim, dropout_rate)

  x = Multiply()([CNN_model, LSTM_model])
  x = Dropout(dropout_rate)(x)
  x = Dense(1000, activation='tanh')(x)
  x = Dropout(dropout_rate)(x)
  output = Dense(num_classes, activation='softmax')(x)
  
  model = Model(inputs= [qs_input, img_input], outputs= output)
  return model

# %% [markdown]
# ### Train

# %%
def Train():
  checkpoint = ModelCheckpoint('model.h5', save_best_only=True)

  model = vanilla(num_classes, DROPOUT_RATE, VOCAB_SIZE, EMBEDDING_DIM)
  model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
  model.summary()
  history = model.fit([train_X_seqs,train_X_ims] ,
                      train_Y, 
                      epochs = EPOCHS, 
                      batch_size = BATCH_SIZE, 
                      callbacks = [checkpoint],
                      validation_data=([val_X_seqs,val_X_ims], val_Y) )
  return history, model

# %%
history, model = Train()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 40)]         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 40, 100)      100000      input_3[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 40, 512)      1255424     embedding_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 40, 512)      0           lstm_2[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 512)          2099200     dropout_4[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 4096)]       0
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         4195328     input_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         525312      dropout_5[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1024)         0           dense_4[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1024)         0           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1000)         1025000     dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 1000)         0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 301)          301301      dropout_7[0][0]
# ==================================================================================================
# Total params: 9,501,565
# Trainable params: 9,501,565
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 47/47 [==============================] - 2s 45ms/step - loss: 5.2068 - accuracy: 0.1673 - val_loss: 3.7449 - val_accuracy: 0.2047
# Epoch 2/50
# 47/47 [==============================] - 2s 46ms/step - loss: 3.8547 - accuracy: 0.1990 - val_loss: 3.1360 - val_accuracy: 0.1893
# Epoch 3/50
# 47/47 [==============================] - 1s 29ms/step - loss: 3.6668 - accuracy: 0.2083 - val_loss: 3.1874 - val_accuracy: 0.2387
# Epoch 4/50
# 47/47 [==============================] - 2s 33ms/step - loss: 3.6005 - accuracy: 0.2213 - val_loss: 3.0275 - val_accuracy: 0.2593
# Epoch 5/50
# 47/47 [==============================] - 1s 30ms/step - loss: 3.9873 - accuracy: 0.2183 - val_loss: 3.2349 - val_accuracy: 0.1680
# Epoch 6/50
# 47/47 [==============================] - 2s 32ms/step - loss: 3.4380 - accuracy: 0.2510 - val_loss: 2.9880 - val_accuracy: 0.4227
# Epoch 7/50
# 47/47 [==============================] - 2s 46ms/step - loss: 3.4828 - accuracy: 0.2840 - val_loss: 2.7504 - val_accuracy: 0.3767
# Epoch 8/50
# 47/47 [==============================] - 1s 30ms/step - loss: 3.2048 - accuracy: 0.3080 - val_loss: 3.1481 - val_accuracy: 0.1967
# Epoch 9/50
# 47/47 [==============================] - 2s 32ms/step - loss: 3.0969 - accuracy: 0.3237 - val_loss: 2.5034 - val_accuracy: 0.4360
# Epoch 10/50
# 47/47 [==============================] - 2s 46ms/step - loss: 2.8484 - accuracy: 0.3677 - val_loss: 2.5027 - val_accuracy: 0.4180
# Epoch 11/50
# 47/47 [==============================] - 1s 30ms/step - loss: 3.1196 - accuracy: 0.3243 - val_loss: 2.5452 - val_accuracy: 0.4460
# Epoch 12/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.7419 - accuracy: 0.3877 - val_loss: 2.5331 - val_accuracy: 0.4313
# Epoch 13/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.6638 - accuracy: 0.3853 - val_loss: 2.5395 - val_accuracy: 0.4440
# Epoch 14/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.5548 - accuracy: 0.4053 - val_loss: 2.5536 - val_accuracy: 0.4207
# Epoch 15/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.5627 - accuracy: 0.4090 - val_loss: 2.6838 - val_accuracy: 0.4160
# Epoch 16/50
# 47/47 [==============================] - 2s 32ms/step - loss: 2.5367 - accuracy: 0.4027 - val_loss: 2.4899 - val_accuracy: 0.4233
# Epoch 17/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.4893 - accuracy: 0.4197 - val_loss: 2.5167 - val_accuracy: 0.4287
# Epoch 18/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.4521 - accuracy: 0.4153 - val_loss: 2.7278 - val_accuracy: 0.3847
# Epoch 19/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.3893 - accuracy: 0.4357 - val_loss: 2.6625 - val_accuracy: 0.3847
# Epoch 20/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.3056 - accuracy: 0.4343 - val_loss: 2.8313 - val_accuracy: 0.3720
# Epoch 21/50
# 47/47 [==============================] - 2s 32ms/step - loss: 2.5495 - accuracy: 0.4137 - val_loss: 2.4573 - val_accuracy: 0.4440
# Epoch 22/50
# 47/47 [==============================] - 2s 46ms/step - loss: 2.1474 - accuracy: 0.4630 - val_loss: 2.3652 - val_accuracy: 0.4653
# Epoch 23/50
# 47/47 [==============================] - 1s 29ms/step - loss: 2.0319 - accuracy: 0.4723 - val_loss: 2.6042 - val_accuracy: 0.3560
# Epoch 24/50
# 47/47 [==============================] - 2s 33ms/step - loss: 1.9364 - accuracy: 0.5093 - val_loss: 2.3141 - val_accuracy: 0.4233
# Epoch 25/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.8605 - accuracy: 0.5270 - val_loss: 2.3494 - val_accuracy: 0.4860
# Epoch 26/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.7988 - accuracy: 0.5250 - val_loss: 2.3238 - val_accuracy: 0.4820
# Epoch 27/50
# 47/47 [==============================] - 2s 32ms/step - loss: 1.7392 - accuracy: 0.5503 - val_loss: 2.3098 - val_accuracy: 0.4873
# Epoch 28/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.7180 - accuracy: 0.5460 - val_loss: 2.3212 - val_accuracy: 0.4480
# Epoch 29/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.6272 - accuracy: 0.5587 - val_loss: 2.3876 - val_accuracy: 0.4720
# Epoch 30/50
# 47/47 [==============================] - 2s 33ms/step - loss: 1.5847 - accuracy: 0.5593 - val_loss: 2.2793 - val_accuracy: 0.4620
# Epoch 31/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.5130 - accuracy: 0.5840 - val_loss: 2.4714 - val_accuracy: 0.4127
# Epoch 32/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.4929 - accuracy: 0.5897 - val_loss: 2.3806 - val_accuracy: 0.4600
# Epoch 33/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.4274 - accuracy: 0.6043 - val_loss: 2.4691 - val_accuracy: 0.4640
# Epoch 34/50
# 47/47 [==============================] - 1s 30ms/step - loss: 1.4226 - accuracy: 0.6083 - val_loss: 2.5453 - val_accuracy: 0.4460
# Epoch 35/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.4166 - accuracy: 0.6020 - val_loss: 2.4227 - val_accuracy: 0.4747
# Epoch 36/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.3033 - accuracy: 0.6407 - val_loss: 2.4801 - val_accuracy: 0.4227
# Epoch 37/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.2896 - accuracy: 0.6487 - val_loss: 2.4174 - val_accuracy: 0.4247
# Epoch 38/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.2670 - accuracy: 0.6493 - val_loss: 2.5856 - val_accuracy: 0.4260
# Epoch 39/50
# 47/47 [==============================] - 1s 30ms/step - loss: 1.2369 - accuracy: 0.6560 - val_loss: 2.5413 - val_accuracy: 0.4387
# Epoch 40/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.1899 - accuracy: 0.6767 - val_loss: 2.8333 - val_accuracy: 0.4467
# Epoch 41/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.1670 - accuracy: 0.6683 - val_loss: 2.6779 - val_accuracy: 0.4340
# Epoch 42/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.1395 - accuracy: 0.6820 - val_loss: 2.6871 - val_accuracy: 0.4473
# Epoch 43/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.1000 - accuracy: 0.7003 - val_loss: 2.6680 - val_accuracy: 0.4500
# Epoch 44/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.0387 - accuracy: 0.7117 - val_loss: 2.7492 - val_accuracy: 0.4433
# Epoch 45/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.0255 - accuracy: 0.7233 - val_loss: 2.8055 - val_accuracy: 0.4447
# Epoch 46/50
# 47/47 [==============================] - 1s 29ms/step - loss: 1.0227 - accuracy: 0.7180 - val_loss: 2.9231 - val_accuracy: 0.4353
# Epoch 47/50
# 47/47 [==============================] - 1s 30ms/step - loss: 0.9961 - accuracy: 0.7320 - val_loss: 2.7942 - val_accuracy: 0.4327
# Epoch 48/50
# 47/47 [==============================] - 1s 29ms/step - loss: 0.9636 - accuracy: 0.7437 - val_loss: 2.8154 - val_accuracy: 0.4360
# Epoch 49/50
# 47/47 [==============================] - 1s 30ms/step - loss: 0.9734 - accuracy: 0.7403 - val_loss: 3.0300 - val_accuracy: 0.3913
# Epoch 50/50
# 47/47 [==============================] - 1s 29ms/step - loss: 0.8920 - accuracy: 0.7580 - val_loss: 2.9684 - val_accuracy: 0.4340

# %%
def plot_accuracy_loss(history):
  acc      = history.history[     'accuracy' ]
  val_acc  = history.history[ 'val_accuracy' ]
  loss     = history.history[    'loss' ]
  val_loss = history.history['val_loss' ]

  epochs   = range(len(acc))

  plt.plot  ( epochs,     acc, label='train_acc' )
  plt.plot  ( epochs, val_acc, label='val_acc' )
  plt.title ('Training and validation accuracy')
  plt.xlabel('epochs')
  plt.ylabel('accuracy')
  plt.legend()
  plt.savefig(BASE_PATH + 'Training and validation accuracy.jpg')
  plt.figure()

  plt.plot  ( epochs,     loss, label='train_loss' )
  plt.plot  ( epochs, val_loss, label='val_loss' )
  plt.title ('Training and validation loss'   )
  plt.legend()
  plt.xlabel('epochs')
  plt.ylabel('loss')
  plt.savefig(BASE_PATH + 'Training and validation loss.jpg')

# %%
plot_accuracy_loss(history)

# %% [markdown]
# ### Evaluate

# %%
def Evaluation(model):
  results = model.evaluate([test_X_seqs,test_X_ims], test_Y, batch_size=64)
  print('test loss, test acc:', results)
Evaluation(model)
# Out:
# 24/24 [==============================] - 0s 9ms/step - loss: 2.9684 - accuracy: 0.4340
# test loss, test acc: [2.968400001525879, 0.4339999854564667]

# %%
def predict(model):
  prediction = predict = model.predict([test_X_seqs,test_X_ims])
  
  # y_pred = []
  # for p in prediction:
  #   y_pred.append(np.argmax(p))
  # y_pred = np.array(y_pred)
  # print(np.where(y_pred == test_answer_indices))
  return prediction

def compare_truth_pred(prediction, num):
  index = np.argmax(prediction[num])
  if(index == num_classes -1):
    show_visualqa(test_qs[num],'نمیدونم', get_test_image_paths().get(test_image_ids[num]))
  else:
    show_visualqa(test_qs[num],all_answers[index], get_test_image_paths().get(test_image_ids[num]))
  show_visualqa(test_qs[num],test_answers[num], get_test_image_paths().get(test_image_ids[num]))

# %%
pred = predict(model)
# Out:
# (array([   1,    6,    7,    9,   10,   11,   13,   17,   18,   22,   25,
#          26,   28,   29,   31,   32,   34,   44,   45,   49,   51,   52,
#          53,   60,   61,   65,   67,   69,   72,   74,   75,   77,   80,
#          81,   82,   85,   90,   94,   98,   99,  100,  102,  107,  109,
#         110,  111,  114,  119,  122,  125,  126,  127,  129,  130,  131,
#         132,  135,  136,  139,  140,  142,  145,  151,  154,  159,  163,
#         166,  169,  171,  172,  175,  176,  178,  179,  182,  184,  185,
#         187,  188,  190,  191,  192,  193,  194,  195,  197,  198,  200,
#         203,  204,  207,  210,  214,  227,  229,  231,  234,  237,  241,
#         242,  243,  245,  247,  249,  254,  260,  262,  268,  272,  276,
#         277,  279,  280,  281,  285,  290,  291,  296,  297,  298,  305,
#         306,  307,  312,  315,  319,  321,  322,  325,  331,  333,  334,
#         335,  336,  337,  338,  339,  341,  345,  346,  348,  350,  352,
#         354,  357,  360,  361,  363,  366,  368,  369,  370,  373,  374,
#         375,  376,  382,  383,  386,  392,  395,  402,  406,  410,  411,
#         413,  416,  417,  418,  420,  422,  428,  431,  432,  433,  434,
#         436,  440,  441,  442,  443,  444,  448,  450,  451,  452,  453,
#         459,  460,  470,  471,  472,  477,  478,  479,  481,  484,  485,
#         486,  487,  488,  489,  491,  492,  494,  495,  497,  498,  502,
#         503,  504,  510,  511,  512,  513,  518,  519,  521,  522,  523,
#         525,  527,  528,  529,  530,  534,  540,  543,  544,  545,  546,
#         549,  552,  554,  556,  557,  558,  559,  562,  563,  566,  570,
#         571,  577,  579,  580,  581,  583,  585,  588,  589,  590,  592,
#         594,  595,  598,  599,  600,  602,  604,  605,  606,  608,  610,
#         612,  614,  615,  616,  619,  620,  624,  625,  628,  629,  631,
#         632,  633,  637,  639,  642,  644,  646,  647,  649,  651,  652,
#         654,  658,  659,  660,  662,  665,  667,  669,  670,  672,  676,
#         677,  680,  684,  686,  687,  688,  693,  694,  695,  698,  700,
#         701,  703,  706,  709,  711,  712,  715,  718,  719,  720,  723,
#         724,  725,  726,  729,  730,  731,  732,  737,  739,  746,  747,
#         749,  751,  756,  762,  763,  765,  767,  769,  770,  778,  779,
#         780,  781,  786,  787,  790,  793,  795,  796,  797,  802,  805,
#         811,  812,  814,  818,  819,  823,  825,  826,  830,  834,  835,
#         836,  838,  846,  848,  851,  854,  855,  856,  858,  860,  864,
#         870,  871,  872,  875,  878,  879,  882,  885,  890,  897,  902,
#         904,  905,  908,  909,  911,  913,  916,  917,  920,  921,  923,
#         925,  929,  930,  931,  936,  937,  941,  943,  944,  945,  946,
#         947,  948,  952,  953,  954,  955,  956,  958,  964,  965,  966,
#         971,  981,  984,  990,  991,  992,  998,  999, 1002, 1003, 1004,
#        1007, 1008, 1012, 1013, 1014, 1016, 1017, 1020, 1021, 1023, 1024,
#        1026, 1033, 1036, 1037, 1038, 1040, 1044, 1048, 1050, 1056, 1058,
#        1059, 1060, 1065, 1066, 1070, 1071, 1072, 1073, 1080, 1081, 1082,
#        1083, 1084, 1085, 1088, 1090, 1091, 1092, 1093, 1099, 1100, 1101,
#        1102, 1103, 1106, 1107, 1108, 1109, 1112, 1114, 1117, 1119, 1122,
#        1123, 1124, 1128, 1130, 1132, 1133, 1135, 1136, 1139, 1143, 1144,
#        1145, 1146, 1150, 1151, 1153, 1154, 1157, 1161, 1164, 1169, 1170,
#        1173, 1175, 1176, 1177, 1178, 1180, 1185, 1194, 1195, 1196, 1197,
#        1199, 1201, 1203, 1205, 1206, 1208, 1211, 1213, 1214, 1215, 1216,
#        1217, 1223, 1224, 1226, 1228, 1230, 1232, 1233, 1237, 1240, 1243,
#        1246, 1247, 1250, 1254, 1256, 1260, 1263, 1265, 1266, 1269, 1271,
#        1272, 1275, 1276, 1277, 1278, 1280, 1284, 1286, 1288, 1296, 1297,
#        1299, 1300, 1308, 1309, 1314, 1315, 1319, 1324, 1326, 1327, 1328,
#        1329, 1331, 1332, 1333, 1337, 1338, 1339, 1340, 1342, 1344, 1345,
#        1346, 1347, 1349, 1354, 1356, 1357, 1364, 1365, 1369, 1370, 1371,
#        1372, 1374, 1375, 1377, 1381, 1382, 1385, 1387, 1389, 1397, 1398,
#        1399, 1400, 1403, 1405, 1407, 1409, 1411, 1412, 1417, 1419, 1421,
#        1423, 1425, 1429, 1431, 1433, 1437, 1438, 1439, 1441, 1442, 1444,
#        1445, 1446, 1449, 1450, 1452, 1453, 1455, 1458, 1461, 1466, 1467,
#        1471, 1472, 1474, 1476, 1477, 1479, 1482, 1486, 1489, 1490, 1491,
#        1493, 1498]),)

# %%
compare_truth_pred(pred,60)
compare_truth_pred(pred,75)
compare_truth_pred(pred,711)

# %%
compare_truth_pred(pred,0)
compare_truth_pred(pred,600)
compare_truth_pred(pred,800)
